# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/citra/blob/main/python_fundamental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
nama="bunga"
umur,tinggi=18,155
#Nama bunga umur saya 22 tahun, tinggi 155
print(f"Nama {nama} umur saya {umur} tahun, tinggi {tinggi}")
# Out:
# Nama bunga umur saya 18 tahun, tinggi 155

# %%
#karena umur saya adalah 22 tahun, saya adalah dewasa

if umur>=20:
  status="Dewasa"
elif umur >=17 :
  status="Remaja"
else:
  status="Anak-anak"

print(f"Karena umur saya adalah {umur} tahun, saya adalah {status}")
# Out:
# Karena umur saya adalah 18 tahun, saya adalah Remaja

# %%
for i in range(5):
  print(f"Halo..{nama}")
# Out:
# Halo..bunga
# Halo..bunga
# Halo..bunga
# Halo..bunga
# Halo..bunga
